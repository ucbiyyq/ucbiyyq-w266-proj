# %%
from data.prep_interim_ca_po import prep_interim_data

# %%
t1 = prep_interim_data("../data/external/ca-po/PURCHASE_ORDER_DATA_EXTRACT_2012-2015_CLEANED.zip")
# Out:
# binky

# %%
t1
# Out:
#        Creation Date Purchase Date Fiscal Year   LPA Number  \
# 0          8/27/2013           NaN   2013-2014   7-12-70-26
# 1          1/29/2014           NaN   2013-2014          NaN
# 2          11/1/2013           NaN   2013-2014          NaN
# 3          6/13/2014      6/5/2014   2013-2014          NaN
# 4          3/12/2014     3/12/2014   2013-2014  1-10-75-60A
# 5          10/9/2014     10/1/2014   2014-2015          NaN
# 6         10/10/2014           NaN   2014-2015  1-14-75-60A
# 7          4/24/2014     4/14/2014   2013-2014          NaN
# 8           2/6/2015           NaN   2014-2015  1-14-75-60A
# 9          8/14/2013     7/26/2013   2013-2014          NaN
# 10         6/26/2013           NaN   2012-2013          NaN
# 11        10/18/2012           NaN   2012-2013          NaN
# 12         6/10/2015      6/8/2015   2014-2015          NaN
# 13          6/9/2015      6/9/2015   2014-2015          NaN
# 14          7/3/2012           NaN   2012-2013     SBP01337
# ...

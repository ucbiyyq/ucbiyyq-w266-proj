# %% [markdown]
# # About

# %%
from numpy import array

from numpy import asarray
from numpy import zeros
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Embedding

import pandas as pd
import janitor
import os

from data.prep_interim_ca_po import prep_interim_data
from data.sample_unspsc_item import sample_unspsc_item

# %% [markdown]
# We are trying to categorize products based on very few samples
#
# we start with the California PO data
#
# Strip it down to just the unspsc code and items names

# %%
p_ca_pos = os.path.join("..", "data", "external", "ca-po", "PURCHASE_ORDER_DATA_EXTRACT_2012-2015_CLEANED.zip")
p_unspsc_items = os.path.join("..", "data", "interim", "unspsc-item.csv")

# %%
prep_interim_data(p_ca_pos, p_unspsc_items)
# Out:
# interim data saved to  ../data/interim/unspsc-item.csv

# %% [markdown]
# double check what we have

# %%
unspsc_items = pd.read_csv(p_unspsc_items, dtype=str).clean_names()

# %%
unspsc_items.head()
# Out:
#   normalized_unspsc                                      item_name
# 0          10101501                                         iphone
# 1          10101502                  Amendment 1 - Option to Renew
# 2          10101502  CANINE, LAW ENFORCEMENT, NON-BITE, SEARCH DOG
# 3          10101502                                        CANINES
# 4          10101502                              CANINES, NON-BITE

# %% [markdown]
# To mimic data from production, we want to limit each class to only have 1 or 2 instances

# %%
unspsc_item_samples = sample_unspsc_item(p_unspsc_items)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-0e69f00404dc> in <module>
# ----> 1 unspsc_item_samples = sample_unspsc_item(p_unspsc_items)
#
# ~/workspaces/ucbiyyq-w266-proj/src/data/sample_unspsc_item.py in sample_unspsc_item(p_in, samples_per_group, samples_overall, random_state)
#       9             data/interim/unspsc-item.csv
#      10     '''
# ---> 11     unspsc_item = pd.read_csv(p_in, dtype=str).clean_names()
#      12     t1 = unspsc_item.groupby("normalized_unspsc")
#      13     t2 = t1.apply(lambda x: x.sample(n = samples_per_group, random_state = 0))
#
# NameError: name 'pd' is not defined

# %%
t1
# Out:
#    normalized_unspsc                                          item_name
# 0           40172206                       2" L hard cop tube (per ft).
# 1           95141903                               ADEC Dental Supplies
# 2           46161702                                          AMBU BAGS
# 3           42211812                            Anti-Embolism Stockings
# 4           42241607                BOOKS,NFPA, 2006 CALIFORNIA EDITION
# 5           24101614                Bags, HEPA replacement vacuum bags,
# 6           85151506                                         Blanket PO
# 7           40141606                                          CARABINER
# 8           12142104                                     CARBON DIOXIDE
# 9           80131502                                     CHILLER RENTAL
# 10          23181801                           COFFEE URNS, TWIN 6 GAL.
# 11          27111815                                   COMBO SQUARE,12"
# 12          27112843                                      Concrete Bits
# 13          70141709                                           Contract
# 14          39121103                           DATA LOGGER WIRING PANEL
# 15          44102103                               DM225 Mailing System
# 16          11162107                                    Dental Supplies
# 17          22101605           District 2 - Asphalt Pavement Scrub Seal
# 18          30171514                                       Door Closers
# 19          40172806                                 ELBOW,BLK 80,45,1"
# 20          40171702         Elbow, 90 degree, Blk Malleable Iron, 1/2"
# 21          14111530    Energizer Max Alkaline AA Batteries, pack of 12
# 22          39131711                FITTING, ELEVATOR BALANCE TAB HINGE
# 23          60105605  FOOD/FY 2013/2014, ALL FOOD TYPE ITEMS, MEAT,D...
# 24          50406605                                  FROZEN VEGETABLES
# 25          39121630                                               Fuse
# 26          27112313     GAP INSPECTION GAUGE 11 1/4, 3/8, 1/2 FITTINGS
# 27          83111901        HEADSET FOR DIRECT PLUG IN/RIGHT ANGLE PLUG
# 28          26111524                                       Helical Gear
# 29          43191514                                     ISAT Phone Pro
# ..               ...                                                ...
# 70          41115324              UV Sensor, Blowdown Tank, Cooling Kit
# 71          41103814                                       Vortex Mixer
# 72          41111976                                 WATER CONSERVATION
# 73          42182009                                       Wallach Tips
# 74          27112838                                   Weed eater parts
# 75          56141603                                         Well Plate
# 76          86131901                                             WestEd
# 77          44103104                    Xerox Second Bias transfer roll
# 78          50413405                                               eggs
# 79          73171503                                   electrical tools
# 80          40173706           flange, slip on 12" raised face 150# ste
# 81          46101504                                           hand gug
# 82          44103004                                   image fuser kits
# 83          13102010                                       lab supplies
# 84          51151729                                         lab supply
# 85          39112505                                          luminaire
# 86          72154022                               maintenance services
# 87          15101508                                                oil
# 88          42151644                              open wide mouth props
# 89          50403003                                 pepper chili green
# 90          50221304                                            potatoe
# 91          43222817                                           repeater
# 92          30191605                                  scaffolding frame
# 93          50402804                                            spinach
# 94          50446116                                   spinach, chopped
# 95          95121705                                   station coverage
# 96          86141602                                  student assistant
# 97          50476405                                      tomatoe paste
# 98          50203101                                   tomatoe products
# 99          25172305                                         windshield
#
# [100 rows x 2 columns]

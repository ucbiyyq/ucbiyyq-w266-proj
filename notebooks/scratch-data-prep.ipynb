# %%
from data.prep_interim_ca_po import prep_interim_data

# %%
p_in = "../data/external/ca-po/PURCHASE_ORDER_DATA_EXTRACT_2012-2015_CLEANED.zip"
p_out = "../data/interim/unspsc-item.csv"
prep_interim_data(p_in, p_out)
# Out:
# interim data saved to  ../data/interim/unspsc-item.csv

# %%
import pandas as pd
import janitor

# %%
p_in = "../data/external/ca-po/PURCHASE_ORDER_DATA_EXTRACT_2012-2015_CLEANED.zip"
p_out = "../data/interim/unspsc-item.csv"

# %%
t1 = pd.read_csv(p_in, dtype=str).clean_names()

# %%
t2 = t1[["normalized_unspsc", "item_name"]]
t3 = t2.drop_duplicates().dropna()
t4 = t3.sort_values(by=["normalized_unspsc", "item_name"]).reset_index(drop = True)

# %%
t4
# Out:
#        normalized_unspsc                                          item_name
# 0               10101501                                             iphone
# 1               10101502                      Amendment 1 - Option to Renew
# 2               10101502      CANINE, LAW ENFORCEMENT, NON-BITE, SEARCH DOG
# 3               10101502                                            CANINES
# 4               10101502                                  CANINES, NON-BITE
# 5               10101502                        Canine, Explosive Detection
# 6               10101502     Canine, Law Enforcement Group 1 with Bite Work
# 7               10101502                   Canine, Law Enforcement, Group 1
# 8               10101502  Canines, Dual Purpose, Selection Tested for Na...
# 9               10101502    Canines, Law Enforcement Group 1 with Bite Work
# 10              10101502  Canines, Pre-Trained or Selection Tested on Na...
# 11              10101502                                  DOGS AND TRAINING
# 12              10101502                          Drug Interdiction Program
# 13              10101502                                      Geese Control
# 14              10101502                  K-9, Labrador Retriever, Non-Bite
# 15              10101502                         K9 Detection Narcotic/Cell
# 16              10101502                            Law Enforcement Canines
# 17              10101502                                          Livestock
# 18              10101502                                         Police Dog
# 19              10101502                                         Police dog
# 20              10101502                                  canine police dog
# 21              10101502                                                dog
# 22              10101502                                              kcups
# 23              10101502                                    keurig machines
# 24              10101502                                         police dog
# 25              10101502                                             tablet
# 26              10101506                                       CHRB Steward
# 27              10101506                                           Contract
# 28              10101506                                 Horse Racing Board
# 29              10101506                       Horse Racing Hearing Officer
# ...                  ...                                                ...
# 215110          95141903                          cure sleeve light guide s
# 215111          95141903                                  denatured alcohol
# 215112          95141903                                    dental Supplies
# 215113          95141903                                 dental prosthetics
# 215114          95141903                                    dental supplies
# 215115          95141903                                      denture boxes
# 215116          95141903                              diamond single use fg
# 215117          95141903                          dispersalloy caps reg set
# 215118          95141903                      distinct pf latex glove small
# 215119          95141903                            elements artridge gutta
# 215120          95141903                           ez view fast tear mounts
# 215121          95141903                            fixodent dent. adhesive
# 215122          95141903                                   flexitime refill
# 215123          95141903                            fuji pluscapsule refill
# 215124          95141903                                    headrest covers
# 215125          95141903                       isolation gown knit cuff reg
# 215126          95141903                               ketac silver aplicap
# 215127          95141903                 maxi gaurd protect eyewear c metal
# 215128          95141903                            omni matrix dental pads
# 215129          95141903                          peri pro developer & fixe
# 215130          95141903                                            rc prep
# 215131          95141903                         reach floss genle flouride
# 215132          95141903                            self seal sterilization
# 215133          95141903                                sodium hypochlorite
# 215134          95141903                                   spatula de 7 wax
# 215135          95141903                          steri-sheild light barrie
# 215136          95141903                                           sure tip
# 215137          95141903                            syringe cover air water
# 215138          95141903                                   tempbond unidose
# 215139          95141903                              vibrakleen ez tablets
#
# [215140 rows x 2 columns]

# %%
t4.to_csv(p_out)

# %% [markdown]
# # Text Classification by Similarity via Siamese Neural Network
#
# Yang Yang Qian
#
# W266 final project

# %%
import os
import sys
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statistics
import janitor
from time import time
import datetime

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Embedding
from keras.layers import LSTM
from keras.layers import Lambda
from keras.layers import Dense, Input, GlobalMaxPooling1D
from keras.layers import Conv1D, MaxPooling1D, Embedding
from keras.layers import Dropout
from keras.initializers import Constant
import keras.backend as K
from keras.optimizers import Adadelta
from keras.optimizers import RMSprop
from keras.optimizers import Adam

from tensorflow.python.keras.layers import Layer

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline

# %%
def prep_interim_data(p_ca_pos, p_out):
    '''
    helper function to prepare the interim dataset
    intention is to mimic the catalog data at the Employer
    we don't need much of the data, just the unspsc codes and the item names
    
    params
        p_ca_pos
            path to the data file, i.e.
            ~/data/external/ca-po/PURCHASE_ORDER_DATA_EXTRACT_2012-2015_CLEANED.zip
        p_unspsc_items
            path to the iterim data file, i.e.
            ~/data/interim/unspsc-item.csv
    '''
    t1 = pd.read_csv(p_ca_pos, dtype=str).clean_names()
    t2 = t1[["normalized_unspsc", "item_name"]]
    t3 = t2.drop_duplicates().dropna()
    t4 = t3.sort_values(by=["normalized_unspsc", "item_name"]).reset_index(drop = True)
    t4.to_csv(p_out, index = False)
    print("interim data saved to ", p_unspsc_items)
    
def sample_unspsc_item(unspsc_items, n_unspsc, n_per_unspsc, min_per_unspsc, max_per_unspsc, random_state = 0):
    '''
    helper function to sample n_per_unspsc number of examples per unspsc code,
    and n_unspsc number of codes overall
    
    params
        unspsc_items
            the data frame that contains the unspsc_items
        n_unspsc
            the number of unspsc codes we want to use in our run
        n_per_unspsc
            the number of items we want per unspsc code
            should be between min_per_unspsc and max_per_unspsc
        min_per_unspsc
            the min number of items we want per class 
        max_per_unspsc
            the max number of items we want per class
        random_state
            to set random seed, default 0
    '''
    # gets count of items per unspsc code, 
    # and filters for codes that have number of items between the min and max
    t1 = unspsc_items.groupby("normalized_unspsc").count().reset_index()
    t2 = t1.item_name.between(min_per_unspsc, max_per_unspsc, inclusive = True)
    t3 = t1[t2]
    relevant = t3
    
    # gets list of unique unspsc codes,
    # and randomly picks n_unspsc number of them for use
    t1 = relevant[["normalized_unspsc"]]
    t2 = t1.drop_duplicates()
    t3 = t2.sample(n = n_unspsc, random_state = random_state).normalized_unspsc
    uc = t3
    
    # gets only the items for the randomly picked unspsc codes
    filtered = unspsc_items[unspsc_items["normalized_unspsc"].isin(uc)]
    
    # gets a sample of items from each randomly picked unspsc code
    t1 = filtered.groupby("normalized_unspsc")
    t2 = t1.apply(lambda x: x.sample(n = n_per_unspsc, replace = False, random_state = random_state))
    t3 = t2.reset_index(drop  = True).sort_values(by = ["normalized_unspsc", "item_name"]).reset_index(drop  = True)
    t4 = t3.drop_duplicates()
    results = t4
    return(results)

def get_embeddings(p_glove):
    '''
    helper function to load GloVe embeddings
    see https://github.com/keras-team/keras/blob/master/examples/pretrained_word_embeddings.py
    
    params
        p_glove
            path to the GloVe embeddings, i.e.
            ~/data/external/glove/glove.6B.100d.txt
    '''
    embeddings_index = {}
    with open(p_glove) as f:
        for line in f:
            word, coefs = line.split(maxsplit=1)
            coefs = np.fromstring(coefs, 'f', sep=' ')
            embeddings_index[word] = coefs

    return(embeddings_index)

def prep_text_and_labels(unspsc_item):
    '''
    helper function to convert unspsc_item_samples into format usable for training
    see https://github.com/keras-team/keras/blob/master/examples/pretrained_word_embeddings.py
    
    params
        unspsc_item
            dataframe of unspsc_item, or some sample of unspsc_item
    '''
    texts = []  # list of text samples
    labels_index = {}  # dictionary mapping label name to numeric id
    labels = []  # list of label ids
    
    texts = unspsc_item.item_name.tolist()
    label_id = 0
    for x in unspsc_item.normalized_unspsc:
        if x in labels_index.keys():
            pass
        else:
            label_id = len(labels_index)
        labels_index[x] = label_id
        labels.append(label_id)
    return(texts, labels_index, labels)

def vectorize_texts(texts, labels, n_max_words, n_padding):
    '''
    helper function to vectorize the text samples into a 2D integer tensor
    see https://github.com/keras-team/keras/blob/master/examples/pretrained_word_embeddings.py
    
    params
        texts
            list of texts
        labels
            list of class labels
    '''
    tokenizer = Tokenizer(num_words = n_max_words)
    tokenizer.fit_on_texts(texts)
    sequences = tokenizer.texts_to_sequences(texts)
    word_index = tokenizer.word_index
    data = pad_sequences(sequences, maxlen = n_padding, padding = "post")
    labels_oh = to_categorical(np.asarray(labels))
    return(data, labels_oh, word_index)

def prep_embedding_matrix(word_index, embeddings_index, n_max_words, embed_dim):
    '''
    helper function to prepare the embedding matrix
    basically looks up the word in the embeddings index created earlier from GloVe
    see https://github.com/keras-team/keras/blob/master/examples/pretrained_word_embeddings.py
    
    params
        word_index
        embeddings_index
        n_max_words
        embed_dim
    '''
    num_words = min(n_max_words, len(word_index) + 1)
    embedding_matrix = np.zeros((num_words, embed_dim))
    for word, i in word_index.items():
        if i >= n_max_words:
            # ignores words that are more than the max number of words allowed
            continue
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            # words not found in embedding index will be all-zeros.
            embedding_matrix[i] = embedding_vector
            
    return(embedding_matrix)

# %%
# paths to data
p_ca_pos = os.path.join("..", "data", "external", "ca-po", "PURCHASE_ORDER_DATA_EXTRACT_2012-2015_CLEANED.zip")
p_unspsc_items = os.path.join("..", "data", "interim", "unspsc-item.csv")
p_glove = os.path.join("..", "data", "external", "glove", "glove.6B.100d.txt")

# some global params
NUM_CLASSES = 1000 # number of classes we want to try for in this run
NUM_EXAMPLES_PER_CLASS = 20 # number of instances we want per class, to simulate catalog data, should be between min and max.
MIN_EXAMPLES_PER_CLASS = 20 # for picking good examples, has to be at least 4, because each class of train and validation sets must have enough examples to form pairs
MAX_EXAMPLES_PER_CLASS = 99999 # for picking good examples, should be greater than MIN_EXAMPLES_PER_CLASS

MAX_NUM_WORDS = 20000 # for vocab size
MAX_SEQUENCE_LENGTH = 20 # for padding
VALIDATION_SPLIT = 0.5 # for train vs validation set size (this is per class split)
EMBEDDING_DIM = 100 # i.e. how wide to make the embedding. Since we are using GloVe, keep at 100

# %% [markdown]
# # Abstract
#
# We explored the use of siamese neural networks for classifying very short documents. We tried both a siamese feed-forward network, and a siamese LSTM, and compared the results against a basic convolutional neural network. We fed the network with word-level embeddings using GloVe. We also used the Manhattan distance function, as recommended by previous work. The results, though not anywhere comparable to state of the art, do still show the expected improvement of the siamese architecture vs the basic neural network.
#
# # Introduction
#
# The motivation for this project was inspired by a project at work. Many businesses buy products and services from outside vendors, from pencils, to hvac services, to racks of servers. As part of the procurement and accounting process, these purchases have to be categorized, so that the business can extract metrics on historical purchases. One of the challenges for a business is to create a catalog of items and services, so that other systems and analysis can have a common reference. Typically this is done manually by human specialists. One intriguing benefit of human classification, is that unlike a neural network which requires large amounts of labelled data, a human can classify an item by reviewing just a few examples (Fei Fei et al 2003, Lake 2011). This project explores siamese neural networks as an architecture that allows neural networks to achieve better results even if we do not have much labelled data.
#
# # Background
#
# The business scenario might be considered a type of one-shot classification, albeit with relaxed constraints. There has been prior work on one-shot classification using a variety of techniques, including a Baeysian framework, and Hierarchical Bayesian Program Learning. Siamese networks worked on by Bromley and LeCun in the 1990s, and were for image matching. (Bromley et al 1993). Koch et al work, in turn, uses the siamese neural network as part of the approach for one-shot learning. (Koch at el 2015). Their architecture is based on a siamese 2d convolutional neural network, with three convolutions, and three pooling layers. They are also using the L1 distance function, and cross-entropy loss as the loss function. Another similar architecture was used by Neculoiu et al, and Mueller et al. (Neculoiu et al 2016, Mueller et al 2016). Their approach used a siamese neural network with a recurrent neural network.
#
# # Methods
#
# By design, catalogs might have many categories, but relatively fewer unique classes per category. To simulate this kind of data, we started with the California Purchase Order data. (Purchase Order Data) We extracted the UNSPSC and Items information. Since the UNSPSC codes are skewed, with some categories having much more items than others, we sampled 1000 UNSPSC codes, and 20 items per UNSPSC codes. Similar to what Mueller et al did, we also converted the item names into embeddings using a pre-trained embedding. We however, used GloVe instead of Word2Vec, as an arbitrary choice.
#
# For the architecture of the neural network, we explored three options:
#
# * Basic CNN (as baseline)
# * Siamese LSTM
# * Siamese feed-forward network
#
# The basic CNN is meant as a baseline. We based the network on the tutorials from the Keras website. (Keras) The embeddings are fed convolution and pooling layers, and then is fed into a softmax layer which tries to classify an item. We expected that this architecture would overfit, because we have many many more classes than we have instances per class. We are expecting our other architectures to perform better than this baseline.
#
# The Siamese LSTM architecture was modelled after the work done by Mueller et al. As explained by Mueller et al, a siamese network allows us to learn a similarity function between documents. Instead of the original multi-class classification task, by using a siamese network, we turned the task into a binary match-vs-not-match task. We split our word-level embeddings into pairs of instances, alternating between match and not-match. The embeddings are fed into stacked LSTMs. According to Mueller et al, we should use Manhattan distance (L1) instead of euclidean distance, because L2 based models might encounter problems with vanishing gradients with almost-identical documents. For the loss function, we also used mean squared error, just as Mueller et al did.
#
# The Siamese FNN architecture is meant to test if the results are better or worse with a simpler architecture. We based the network on the tutorials from the Keras examples. (Keras) We split our word-level embeddings into pairs of instances, alternating between match and not-match. The embeddings are fed into three dense layers. For the distance function, we also decided to use Euclidean distance (L2). For the loss function, we still used mean squared error.

# %%
# gets and preps interim data
# We don't need all the PO data, so just stripping it down to item and unspsc codes
prep_interim_data(p_ca_pos, p_unspsc_items)
# Out:
# interim data saved to  ../data/interim/unspsc-item.csv

# %%
# gets interim data
unspsc_items = pd.read_csv(p_unspsc_items, dtype=str).clean_names()

# %% [markdown]
# we want to get a sample of the unspsc codes and items
#
# even if unbalanced, to mimic catalogs, we would want only a couple of items per unspsc code

# %% [markdown]
# Note most unspsc codes only have a few items, which is quite similar to the real data that we don't have access to. Average items per code is 3. To make the California data reflect the real data, we need to constrain our data so that we only have a few items per unspsc code. But for the train-validate split to work, we need at least two items per code per training & validation.

# %%
t1 = unspsc_items.groupby("normalized_unspsc").count()
t2 = t1.item_name.tolist()
print("median items per unspsc code", statistics.median(t2))

fig, ax = plt.subplots()
t1.hist(ax=ax, bins=100, bottom=0.1)
ax.set_yscale("log")
# Out:
# median items per unspsc code 3

# %%
# preps samples
unspsc_item_samples = sample_unspsc_item(
    unspsc_items, 
    n_unspsc = NUM_CLASSES, 
    n_per_unspsc = NUM_EXAMPLES_PER_CLASS,
    min_per_unspsc = MIN_EXAMPLES_PER_CLASS,
    max_per_unspsc = MAX_EXAMPLES_PER_CLASS, 
    random_state = 0)

print("samples shape", unspsc_item_samples.shape)
print("items per unspsc code", unspsc_item_samples.groupby("normalized_unspsc").count().item_name.unique())
# Out:
# samples shape (20000, 2)
# items per unspsc code [20]

# %%
# prep text and lables
texts, labels_index, labels = prep_text_and_labels(unspsc_item_samples)

# note, the labels gets converted to a one-hot class matrix, 
# so that we later we can calculate cross-entropy loss against it
data, labels_oh, word_index = vectorize_texts(texts, labels, MAX_NUM_WORDS, MAX_SEQUENCE_LENGTH)
print("Unique words", len(word_index))
print("data shape", data.shape)
print("labels one-hot shape", labels_oh.shape)
# Out:
# Unique words 14011
# data shape (20000, 20)
# labels one-hot shape (20000, 1000)

# %%
t1 = data[:, 19] > 0
np.unique(t1)
# Out:
# array([False])

# %%
# get embeddings
embeddings_index = get_embeddings(p_glove)
print("embeddings_index length", len(embeddings_index))

# get embedding matrix
embedding_matrix = prep_embedding_matrix(
    word_index = word_index, 
    embeddings_index = embeddings_index, 
    n_max_words = MAX_NUM_WORDS, 
    embed_dim = EMBEDDING_DIM)

print("embedding_matrix shape", embedding_matrix.shape)

# load pre-trained word embeddings into an Embedding layer
# we set trainable = False so as to keep the embeddings fixed
# because we are using the GloVe embeddings, and are not training our own embeddings
num_words = min(MAX_NUM_WORDS, len(word_index) + 1)
embedding_layer = Embedding(
    num_words,
    EMBEDDING_DIM,
    embeddings_initializer = Constant(embedding_matrix),
    input_length = MAX_SEQUENCE_LENGTH,
    trainable = False)

print("number of words ", num_words)
print(embedding_layer)
# Out:
# embeddings_index length 400000
# embedding_matrix shape (14012, 100)
# number of words  14012
# <keras.layers.embeddings.Embedding object at 0x7fd68575ff98>

# %% [markdown]
# # Basic CNN
#
# * input > (1x convolutional layers, and 1x pooling layers) > softmax
# * loss function = categorical crossentropy loss
#
# We're expecting this baseline model to overfit, because there are relatively more classes than instances

# %%
def g1(
    data, 
    labels, 
    labels_oh, 
    labels_index, 
    embedding_layer,
    split,
    seq_shape):
    '''
    1D CNN, because we're dealing with short text phrases, not images, 1D instead of 2D CNN
    
    params
        data
            matrix of vectorized text data
        labels
            array of label ids for each of the texts
        labels_oh
            one-hot matrix of labels for each of the texts
        labels_index
            dictionary of labels and ids
        embedding_layer
            the frozen embedding layer we defined with GloVe
        split
            float that represnets the validation split size
        seq_shape
            sequence length, i.e. the length with padding
    
    see https://blog.goodaudience.com/introduction-to-1d-convolutional-neural-networks-in-keras-for-time-sequences-3a7ff801a2cf
    see https://github.com/keras-team/keras/blob/master/examples/pretrained_word_embeddings.py
    '''
    
    def split_data(data, labels, labels_oh, split, random_state = 0):
        '''
        split the data into a training set and a validation set
        note for this to simulate catalog data, we need stratified split, per class

        params
            data
                matrix of vectorized text data
            labels
                array of label ids for each of the texts
            labels_oh
                one-hot matrix of labels for each of the texts
            split
                float that represnets the validation split size
        '''
        np.random.seed(random_state)
        x_train = np.empty((0, data[0].shape[0]))
        y_train = np.empty((0, labels_oh[0].shape[0]))
        x_val = np.empty((0, data[0].shape[0]))
        y_val = np.empty((0, labels_oh[0].shape[0]))

        # gets unique classes
        uc = np.unique(labels)

        # for each class, 
        # subsets the data and labels_oh, 
        # and assigns some to train, some to validation 
        # this makes sure each class has some representation in train, and some in validation
        for c in uc:
            t1 = (labels == c)
            data_c = data[t1]
            labels_oh_c = labels_oh[t1]
            indices = np.arange(data_c.shape[0])
            np.random.shuffle(indices)
            data_c = data_c[indices]
            labels_oh_c = labels_oh_c[indices]
            num_validation_samples = int(split * data_c.shape[0])
            x_train_c = data_c[:-num_validation_samples]
            y_train_c = labels_oh_c[:-num_validation_samples]
            x_val_c = data_c[-num_validation_samples:]
            y_val_c = labels_oh_c[-num_validation_samples:]

            x_train = np.concatenate([x_train, x_train_c])
            y_train = np.concatenate([y_train, y_train_c])
            x_val = np.concatenate([x_val, x_val_c])
            y_val = np.concatenate([y_val, y_val_c])

        return(x_train, y_train, x_val, y_val)
    
    batch_size = 128
    n_epoch = 50
    learning_rate = 0.001
    
    # split the vectorized data into train and validation sets
    x_train, y_train, x_val, y_val = split_data(data, labels, labels_oh, split)
    
    # 1D CNN
    sequence_input = Input(shape = (seq_shape,), dtype = "int32")
    embedded_sequences = embedding_layer(sequence_input)
    x = Conv1D(128, 5, activation = "relu")(embedded_sequences)
#     x = MaxPooling1D(5)(x)
#     x = Conv1D(128, 5, activation = "relu")(x)
#     x = MaxPooling1D(5)(x)
#     x = Conv1D(128, 5, activation = "relu")(x)
    x = GlobalMaxPooling1D()(x)
    x = Dense(128, activation = "relu")(x)
    preds = Dense(len(labels_index), activation = "softmax")(x)

    # RMSprop optimizer
    optimizer = RMSprop(lr =learning_rate)
    
    model = Model(sequence_input, preds)
    model.compile(loss = "categorical_crossentropy", optimizer = optimizer, metrics = ["accuracy"])
    model.summary()
    
    # Start training
    training_start_time = time() # this is just for timing the runs
    
    model_trained = model.fit(x_train, y_train,
              batch_size = batch_size,
              epochs = n_epoch,
              validation_data = (x_val, y_val))
    
    print("Training time finished.\n{} epochs in {}".format(n_epoch, datetime.timedelta(seconds=time()-training_start_time)))
    
    return(model_trained)
    
m1 = g1( data = data, 
    labels = labels, 
    labels_oh = labels_oh, 
    labels_index = labels_index, 
    embedding_layer = embedding_layer,
    split = VALIDATION_SPLIT,
    seq_shape = MAX_SEQUENCE_LENGTH)
# Out:
# WARNING:tensorflow:From /home/yangyq/anaconda3/envs/w266/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 20)                0
# _________________________________________________________________
# embedding_3 (Embedding)      (None, 20, 100)           1401200
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 16, 128)           64128
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_2 (Dense)              (None, 1000)              129000
# =================================================================
# Total params: 1,610,840
# Trainable params: 209,640
# Non-trainable params: 1,401,200
# _________________________________________________________________
# WARNING:tensorflow:From /home/yangyq/anaconda3/envs/w266/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/yangyq/anaconda3/envs/w266/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Train on 10000 samples, validate on 10000 samples
# Epoch 1/50
# 10000/10000 [==============================] - 5s 510us/step - loss: 6.8538 - acc: 0.0071 - val_loss: 6.5837 - val_acc: 0.0218
# Epoch 2/50
# 10000/10000 [==============================] - 5s 473us/step - loss: 6.1615 - acc: 0.0415 - val_loss: 5.8888 - val_acc: 0.0661
# Epoch 3/50
# 10000/10000 [==============================] - 5s 471us/step - loss: 5.3539 - acc: 0.1086 - val_loss: 5.4564 - val_acc: 0.0978
# Epoch 4/50
# 10000/10000 [==============================] - 5s 471us/step - loss: 4.7328 - acc: 0.1728 - val_loss: 5.1599 - val_acc: 0.1247
# Epoch 5/50
# 10000/10000 [==============================] - 5s 468us/step - loss: 4.2433 - acc: 0.2336 - val_loss: 4.9816 - val_acc: 0.1507
# Epoch 6/50
# 10000/10000 [==============================] - 5s 471us/step - loss: 3.8672 - acc: 0.2823 - val_loss: 4.8409 - val_acc: 0.1723
# Epoch 7/50
# 10000/10000 [==============================] - 5s 474us/step - loss: 3.5460 - acc: 0.3300 - val_loss: 4.7990 - val_acc: 0.1880
# Epoch 8/50
# 10000/10000 [==============================] - 5s 476us/step - loss: 3.2814 - acc: 0.3679 - val_loss: 4.7185 - val_acc: 0.2069
# Epoch 9/50
# 10000/10000 [==============================] - 5s 469us/step - loss: 3.0582 - acc: 0.4038 - val_loss: 4.7260 - val_acc: 0.2090
# Epoch 10/50
# 10000/10000 [==============================] - 5s 464us/step - loss: 2.8582 - acc: 0.4378 - val_loss: 4.7413 - val_acc: 0.2146
# Epoch 11/50
# 10000/10000 [==============================] - 5s 474us/step - loss: 2.6897 - acc: 0.4598 - val_loss: 4.7253 - val_acc: 0.2204
# Epoch 12/50
# 10000/10000 [==============================] - 5s 470us/step - loss: 2.5255 - acc: 0.4899 - val_loss: 4.7533 - val_acc: 0.2234
# Epoch 13/50
# 10000/10000 [==============================] - 5s 468us/step - loss: 2.3882 - acc: 0.5124 - val_loss: 4.9276 - val_acc: 0.2199
# Epoch 14/50
# 10000/10000 [==============================] - 5s 470us/step - loss: 2.2542 - acc: 0.5352 - val_loss: 4.9183 - val_acc: 0.2184
# Epoch 15/50
# 10000/10000 [==============================] - 5s 467us/step - loss: 2.1299 - acc: 0.5608 - val_loss: 4.9132 - val_acc: 0.2326
# Epoch 16/50
# 10000/10000 [==============================] - 5s 474us/step - loss: 2.0252 - acc: 0.5800 - val_loss: 5.0031 - val_acc: 0.2288
# Epoch 17/50
# 10000/10000 [==============================] - 5s 469us/step - loss: 1.9237 - acc: 0.5942 - val_loss: 5.0656 - val_acc: 0.2314
# Epoch 18/50
# 10000/10000 [==============================] - 5s 469us/step - loss: 1.8262 - acc: 0.6161 - val_loss: 5.1641 - val_acc: 0.2283
# Epoch 19/50
# 10000/10000 [==============================] - 5s 476us/step - loss: 1.7405 - acc: 0.6314 - val_loss: 5.2245 - val_acc: 0.2314
# Epoch 20/50
# 10000/10000 [==============================] - 5s 468us/step - loss: 1.6641 - acc: 0.6472 - val_loss: 5.3718 - val_acc: 0.2295
# Epoch 21/50
# 10000/10000 [==============================] - 5s 467us/step - loss: 1.5919 - acc: 0.6596 - val_loss: 5.3847 - val_acc: 0.2293
# Epoch 22/50
# 10000/10000 [==============================] - 5s 470us/step - loss: 1.5208 - acc: 0.6707 - val_loss: 5.5168 - val_acc: 0.2270
# Epoch 23/50
# 10000/10000 [==============================] - 5s 476us/step - loss: 1.4596 - acc: 0.6864 - val_loss: 5.5358 - val_acc: 0.2331
# Epoch 24/50
# 10000/10000 [==============================] - 5s 478us/step - loss: 1.3996 - acc: 0.6956 - val_loss: 5.6836 - val_acc: 0.2252
# Epoch 25/50
# 10000/10000 [==============================] - 5s 466us/step - loss: 1.3512 - acc: 0.7027 - val_loss: 5.7830 - val_acc: 0.2273
# Epoch 26/50
# 10000/10000 [==============================] - 5s 467us/step - loss: 1.3006 - acc: 0.7105 - val_loss: 5.8118 - val_acc: 0.2231
# Epoch 27/50
# 10000/10000 [==============================] - 5s 467us/step - loss: 1.2634 - acc: 0.7187 - val_loss: 5.8893 - val_acc: 0.2260
# Epoch 28/50
# 10000/10000 [==============================] - 5s 468us/step - loss: 1.2264 - acc: 0.7249 - val_loss: 6.0137 - val_acc: 0.2224
# Epoch 29/50
# 10000/10000 [==============================] - 5s 470us/step - loss: 1.1874 - acc: 0.7330 - val_loss: 6.0563 - val_acc: 0.2235
# Epoch 30/50
# 10000/10000 [==============================] - 5s 470us/step - loss: 1.1571 - acc: 0.7363 - val_loss: 6.1517 - val_acc: 0.2211
# Epoch 31/50
# 10000/10000 [==============================] - 5s 474us/step - loss: 1.1256 - acc: 0.7409 - val_loss: 6.2171 - val_acc: 0.2246
# Epoch 32/50
# 10000/10000 [==============================] - 5s 466us/step - loss: 1.1029 - acc: 0.7445 - val_loss: 6.3102 - val_acc: 0.2219
# Epoch 33/50
# 10000/10000 [==============================] - 5s 477us/step - loss: 1.0739 - acc: 0.7496 - val_loss: 6.4513 - val_acc: 0.2180
# Epoch 34/50
# 10000/10000 [==============================] - 5s 473us/step - loss: 1.0608 - acc: 0.7504 - val_loss: 6.4621 - val_acc: 0.2201
# Epoch 35/50
# 10000/10000 [==============================] - 5s 468us/step - loss: 1.0355 - acc: 0.7527 - val_loss: 6.5745 - val_acc: 0.2152
# Epoch 36/50
# 10000/10000 [==============================] - 5s 474us/step - loss: 1.0208 - acc: 0.7556 - val_loss: 6.5984 - val_acc: 0.2165
# Epoch 37/50
# 10000/10000 [==============================] - 5s 486us/step - loss: 1.0022 - acc: 0.7615 - val_loss: 6.7032 - val_acc: 0.2157
# Epoch 38/50
# 10000/10000 [==============================] - 5s 491us/step - loss: 0.9942 - acc: 0.7584 - val_loss: 6.7471 - val_acc: 0.2167
# Epoch 39/50
# 10000/10000 [==============================] - 5s 471us/step - loss: 0.9731 - acc: 0.7632 - val_loss: 6.9003 - val_acc: 0.2139
# Epoch 40/50
# 10000/10000 [==============================] - 5s 490us/step - loss: 0.9643 - acc: 0.7608 - val_loss: 6.9174 - val_acc: 0.2153
# Epoch 41/50
# 10000/10000 [==============================] - 5s 468us/step - loss: 0.9554 - acc: 0.7619 - val_loss: 6.9225 - val_acc: 0.2147
# Epoch 42/50
# 10000/10000 [==============================] - 5s 511us/step - loss: 0.9439 - acc: 0.7656 - val_loss: 6.9435 - val_acc: 0.2135
# Epoch 43/50
# 10000/10000 [==============================] - 5s 473us/step - loss: 0.9335 - acc: 0.7675 - val_loss: 7.0665 - val_acc: 0.2111
# Epoch 44/50
# 10000/10000 [==============================] - 5s 469us/step - loss: 0.9313 - acc: 0.7652 - val_loss: 7.0380 - val_acc: 0.2115
# Epoch 45/50
# 10000/10000 [==============================] - 5s 469us/step - loss: 0.9225 - acc: 0.7663 - val_loss: 7.1356 - val_acc: 0.2084
# Epoch 46/50
# 10000/10000 [==============================] - 5s 469us/step - loss: 0.9171 - acc: 0.7676 - val_loss: 7.2232 - val_acc: 0.2111
# Epoch 47/50
# 10000/10000 [==============================] - 5s 467us/step - loss: 0.9119 - acc: 0.7682 - val_loss: 7.1850 - val_acc: 0.2125
# Epoch 48/50
# 10000/10000 [==============================] - 5s 473us/step - loss: 0.9074 - acc: 0.7677 - val_loss: 7.2413 - val_acc: 0.2169
# Epoch 49/50
# 10000/10000 [==============================] - 5s 474us/step - loss: 0.9034 - acc: 0.7671 - val_loss: 7.2880 - val_acc: 0.2182
# Epoch 50/50
# 10000/10000 [==============================] - 5s 473us/step - loss: 0.9016 - acc: 0.7669 - val_loss: 7.3206 - val_acc: 0.2139
# Training time finished.
# 50 epochs in 0:03:57.093428

# %%
# Plot accuracy
plt.plot(m1.history["acc"])
plt.plot(m1.history["val_acc"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train", "Validation"], loc = "upper left")
plt.show()

# Plot loss
plt.plot(m1.history["loss"])
plt.plot(m1.history["val_loss"])
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Validation"], loc = "upper right")
plt.show()

# %% [markdown]
# # Siamese LSTM, flavor 1
#
# * input > embedding > 8x LSTM > distance
# * distance function = exponential negative Manhattan distance
# * loss function = mean squared error
# * optimizer = Adadelta

# %%
def g2(
    data, 
    labels, 
    embedding_layer,
    split,
    seq_shape):
    '''
    basic siamese network with LSTM
    
    params
        data
        labels
        embedding_layer
        split
        seq_shape
    
    see
    https://keras.io/examples/mnist_siamese/
    https://github.com/keras-team/keras/blob/master/examples/mnist_siamese.py
    https://sorenbouma.github.io/blog/oneshot/
    https://towardsdatascience.com/one-shot-learning-with-siamese-networks-using-keras-17f34e75bb3d
    https://github.com/sorenbouma/keras-oneshot/blob/master/SiameseNet.ipynb
    
    https://medium.com/mlreview/implementing-malstm-on-kaggles-quora-question-pairs-competition-8b31b0b16a07
    https://github.com/eliorc/Medium/blob/master/MaLSTM.ipynb
    https://www.aaai.org/ocs/index.php/AAAI/AAAI16/paper/download/12195/12023
    '''
    
    def split_data(data, labels, split, random_state = 0):
        '''
        split the data into a training set and a validation set
        note for this to simulate catalog data, we need stratified split, per class

        params
            data
                matrix of vectorized text data
            labels
                array of label ids for each of the texts
            labels_oh
                one-hot matrix of labels for each of the texts
            split
                float that represnets the validation split size
        '''
        np.random.seed(random_state)
        x_train = np.empty((0, data[0].shape[0]))
        y_train = np.empty((0, ))
        x_val = np.empty((0, data[0].shape[0]))
        y_val = np.empty((0, ))

        # gets unique classes
        uc = np.unique(labels)

        # for each class, 
        # subsets the data and labels, 
        # and assigns some to train, some to validation 
        # this makes sure each class has some representation in train, and some in validation
        for c in uc:
            t1 = (labels == c)
            t2 = np.array(labels)
            data_c = data[t1]
            labels_c = t2[t1]
            indices = np.arange(data_c.shape[0])
            np.random.shuffle(indices)
            data_c = data_c[indices]
            labels_c = labels_c[indices]
            num_validation_samples = int(split * data_c.shape[0])
            x_train_c = data_c[:-num_validation_samples]
            y_train_c = labels_c[:-num_validation_samples]
            x_val_c = data_c[-num_validation_samples:]
            y_val_c = labels_c[-num_validation_samples:]
            
            x_train = np.concatenate([x_train, x_train_c])
            y_train = np.concatenate([y_train, y_train_c])
            x_val = np.concatenate([x_val, x_val_c])
            y_val = np.concatenate([y_val, y_val_c])

        return(x_train, y_train, x_val, y_val)
    
    def create_pairs(x, unspsc_indices, num_classes):
        '''
        Positive and negative pair creation.
        Alternates between positive and negative pairs.

        params
            x
                either the train or validation set
            unspsc_indices
                indices of which x belongs to which class
            num_classes
                number of unique classes

        see https://github.com/keras-team/keras/blob/master/examples/mnist_siamese.py
        '''
        pairs = []
        labels = []
        n = min([len(unspsc_indices[d]) for d in range(num_classes)]) - 1
        for d in range(num_classes):
            for i in range(n):
                z1, z2 = unspsc_indices[d][i], unspsc_indices[d][i + 1]
                pairs += [[x[z1], x[z2]]]
                inc = random.randrange(1, num_classes)
                dn = (d + inc) % num_classes
                z1, z2 = unspsc_indices[d][i], unspsc_indices[dn][i]
                pairs += [[x[z1], x[z2]]]
                labels += [1, 0]
        return np.array(pairs), np.array(labels)
    
    def exponent_neg_manhattan_distance(a, b):
        ''' 
        Helper function for the similarity estimate of the LSTMs outputs
        params
            a
                the "left" text
            b
                the "right" text
        '''
        return K.exp(-K.sum(K.abs(a-b), axis=1, keepdims=True))
    
    
    
    n_hidden = 8
    gradient_clipping_norm = 1.25
    batch_size = 128
    n_epoch = 50
    
    
    # split the vectorized data into train and validation sets
    x_train, y_train, x_val, y_val = split_data(data, labels, split)
    
    # gets unique classes
    num_classes = len(np.unique(labels))
    
    # creates the pairs
    unspsc_indices = [np.where(y_train == i)[0] for i in range(num_classes)]
    tr_pairs, tr_y = create_pairs(x_train, unspsc_indices, num_classes)

    unspsc_indices = [np.where(y_val == i)[0] for i in range(num_classes)]
    vl_pairs, vl_y = create_pairs(x_val, unspsc_indices, num_classes)
    
    # network definition
    input_a = Input(shape = (seq_shape,), dtype = "int32")
    input_b = Input(shape = (seq_shape,), dtype = "int32")
    encoded_a = embedding_layer(input_a)
    encoded_b = embedding_layer(input_b)
    
    # this will be shared between a and b
    shared_lstm = LSTM(n_hidden)
    shared_a = shared_lstm(encoded_a)
    shared_b = shared_lstm(encoded_b)
    
    # Calculates the distance as defined by the MaLSTM model
    # see
    # https://www.aaai.org/ocs/index.php/AAAI/AAAI16/paper/download/12195/12023
    distance = Lambda(
        function = lambda x: exponent_neg_manhattan_distance(x[0], x[1]),
        output_shape = lambda x: (x[0][0], 1)
    )([shared_a, shared_b])
    
    # Pack it all up into a model
    model = Model([input_a, input_b], [distance])
    
    # Adadelta optimizer, with gradient clipping by norm
#     optimizer = Adadelta(clipnorm = gradient_clipping_norm)
    optimizer = Adadelta()
    
    model.compile(loss = "mean_squared_error", optimizer = optimizer, metrics = ["accuracy"])
    model.summary()
    
    # Start training
    training_start_time = time() # this is just for timing the runs
    
    # fit model on, 
    #    the tr_pairs 0 texts (left side) vs the tr_pairs 1 texts (right side)
    #    along with the binary labels if they are same class or not tr_y
    # validate model on,
    #    the vl_pairs 0 texts (left side) vs the vl_pairs 1 texts (right side)
    #    and their true binary labels if they are same class or not vl_y
    model_trained = model.fit([tr_pairs[:, 0], tr_pairs[:, 1]], tr_y,
          batch_size = batch_size,
          epochs = n_epoch,
          validation_data = ([vl_pairs[:, 0], vl_pairs[:, 1]], vl_y))
    
    print("Training time finished.\n{} epochs in {}".format(n_epoch, datetime.timedelta(seconds=time()-training_start_time)))
    
    return(model_trained)

m2 = g2( data = data, 
    labels = labels, 
    embedding_layer = embedding_layer,
    split = VALIDATION_SPLIT,
    seq_shape = MAX_SEQUENCE_LENGTH)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 20)           0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            (None, 20)           0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 20, 100)      1401200     input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 8)            3488        embedding_3[1][0]
#                                                                  embedding_3[2][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1)            0           lstm_1[0][0]
#                                                                  lstm_1[1][0]
# ==================================================================================================
# Total params: 1,404,688
# Trainable params: 3,488
# Non-trainable params: 1,401,200
# __________________________________________________________________________________________________
# Train on 18000 samples, validate on 18000 samples
# Epoch 1/50
# 18000/18000 [==============================] - 8s 443us/step - loss: 0.2789 - acc: 0.5691 - val_loss: 0.2352 - val_acc: 0.6123
# Epoch 2/50
# 18000/18000 [==============================] - 7s 365us/step - loss: 0.2263 - acc: 0.6298 - val_loss: 0.2235 - val_acc: 0.6344
# Epoch 3/50
# 18000/18000 [==============================] - 6s 358us/step - loss: 0.2160 - acc: 0.6537 - val_loss: 0.2154 - val_acc: 0.6512
# Epoch 4/50
# 18000/18000 [==============================] - 7s 364us/step - loss: 0.2087 - acc: 0.6662 - val_loss: 0.2107 - val_acc: 0.6665
# Epoch 5/50
# 18000/18000 [==============================] - 7s 362us/step - loss: 0.2030 - acc: 0.6776 - val_loss: 0.2078 - val_acc: 0.6715
# Epoch 6/50
# 18000/18000 [==============================] - 7s 363us/step - loss: 0.1987 - acc: 0.6882 - val_loss: 0.2063 - val_acc: 0.6719
# Epoch 7/50
# 18000/18000 [==============================] - 7s 366us/step - loss: 0.1958 - acc: 0.6953 - val_loss: 0.2048 - val_acc: 0.6774
# Epoch 8/50
# 18000/18000 [==============================] - 6s 359us/step - loss: 0.1930 - acc: 0.7008 - val_loss: 0.2031 - val_acc: 0.6824
# Epoch 9/50
# 18000/18000 [==============================] - 6s 360us/step - loss: 0.1907 - acc: 0.7076 - val_loss: 0.2023 - val_acc: 0.6828
# Epoch 10/50
# 18000/18000 [==============================] - 7s 364us/step - loss: 0.1886 - acc: 0.7087 - val_loss: 0.2012 - val_acc: 0.6862
# Epoch 11/50
# 18000/18000 [==============================] - 7s 368us/step - loss: 0.1865 - acc: 0.7152 - val_loss: 0.2005 - val_acc: 0.6903
# Epoch 12/50
# 18000/18000 [==============================] - 7s 376us/step - loss: 0.1851 - acc: 0.7187 - val_loss: 0.2011 - val_acc: 0.6857
# Epoch 13/50
# 18000/18000 [==============================] - 7s 380us/step - loss: 0.1835 - acc: 0.7224 - val_loss: 0.1994 - val_acc: 0.6909
# Epoch 14/50
# 18000/18000 [==============================] - 7s 364us/step - loss: 0.1823 - acc: 0.7259 - val_loss: 0.2005 - val_acc: 0.6890
# Epoch 15/50
# 18000/18000 [==============================] - 6s 352us/step - loss: 0.1808 - acc: 0.7274 - val_loss: 0.1998 - val_acc: 0.6891
# Epoch 16/50
# 18000/18000 [==============================] - 6s 360us/step - loss: 0.1799 - acc: 0.7282 - val_loss: 0.1992 - val_acc: 0.6909
# Epoch 17/50
# 18000/18000 [==============================] - 7s 362us/step - loss: 0.1786 - acc: 0.7317 - val_loss: 0.1995 - val_acc: 0.6893
# Epoch 18/50
# 18000/18000 [==============================] - 7s 367us/step - loss: 0.1777 - acc: 0.7348 - val_loss: 0.1993 - val_acc: 0.6896
# Epoch 19/50
# 18000/18000 [==============================] - 6s 357us/step - loss: 0.1766 - acc: 0.7349 - val_loss: 0.1986 - val_acc: 0.6911
# Epoch 20/50
# 18000/18000 [==============================] - 6s 359us/step - loss: 0.1755 - acc: 0.7383 - val_loss: 0.1989 - val_acc: 0.6865
# Epoch 21/50
# 18000/18000 [==============================] - 6s 359us/step - loss: 0.1749 - acc: 0.7395 - val_loss: 0.1989 - val_acc: 0.6908
# Epoch 22/50
# 18000/18000 [==============================] - 7s 363us/step - loss: 0.1739 - acc: 0.7420 - val_loss: 0.1985 - val_acc: 0.6898
# Epoch 23/50
# 18000/18000 [==============================] - 6s 356us/step - loss: 0.1731 - acc: 0.7443 - val_loss: 0.1990 - val_acc: 0.6902
# Epoch 24/50
# 18000/18000 [==============================] - 6s 346us/step - loss: 0.1724 - acc: 0.7459 - val_loss: 0.1992 - val_acc: 0.6904
# Epoch 25/50
# 18000/18000 [==============================] - 7s 364us/step - loss: 0.1715 - acc: 0.7473 - val_loss: 0.1988 - val_acc: 0.6887
# Epoch 26/50
# 18000/18000 [==============================] - 7s 375us/step - loss: 0.1709 - acc: 0.7474 - val_loss: 0.1988 - val_acc: 0.6914
# Epoch 27/50
# 18000/18000 [==============================] - 7s 365us/step - loss: 0.1701 - acc: 0.7529 - val_loss: 0.1983 - val_acc: 0.6909
# Epoch 28/50
# 18000/18000 [==============================] - 6s 358us/step - loss: 0.1696 - acc: 0.7512 - val_loss: 0.1986 - val_acc: 0.6899
# Epoch 29/50
# 18000/18000 [==============================] - 6s 361us/step - loss: 0.1689 - acc: 0.7546 - val_loss: 0.1990 - val_acc: 0.6883
# Epoch 30/50
# 18000/18000 [==============================] - 6s 358us/step - loss: 0.1683 - acc: 0.7543 - val_loss: 0.1984 - val_acc: 0.6917
# Epoch 31/50
# 18000/18000 [==============================] - 7s 366us/step - loss: 0.1675 - acc: 0.7579 - val_loss: 0.1988 - val_acc: 0.6897
# Epoch 32/50
# 18000/18000 [==============================] - 7s 364us/step - loss: 0.1674 - acc: 0.7555 - val_loss: 0.1989 - val_acc: 0.6887
# Epoch 33/50
# 18000/18000 [==============================] - 7s 369us/step - loss: 0.1667 - acc: 0.7597 - val_loss: 0.1987 - val_acc: 0.6911
# Epoch 34/50
# 18000/18000 [==============================] - 7s 371us/step - loss: 0.1663 - acc: 0.7587 - val_loss: 0.1991 - val_acc: 0.6916
# Epoch 35/50
# 18000/18000 [==============================] - 6s 357us/step - loss: 0.1655 - acc: 0.7626 - val_loss: 0.1987 - val_acc: 0.6951
# Epoch 36/50
# 18000/18000 [==============================] - 7s 362us/step - loss: 0.1651 - acc: 0.7622 - val_loss: 0.1993 - val_acc: 0.6919
# Epoch 37/50
# 18000/18000 [==============================] - 7s 364us/step - loss: 0.1648 - acc: 0.7637 - val_loss: 0.1988 - val_acc: 0.6905
# Epoch 38/50
# 18000/18000 [==============================] - 6s 357us/step - loss: 0.1642 - acc: 0.7628 - val_loss: 0.1996 - val_acc: 0.6884
# Epoch 39/50
# 18000/18000 [==============================] - 6s 356us/step - loss: 0.1637 - acc: 0.7621 - val_loss: 0.1987 - val_acc: 0.6920
# Epoch 40/50
# 18000/18000 [==============================] - 6s 358us/step - loss: 0.1634 - acc: 0.7619 - val_loss: 0.1982 - val_acc: 0.6922
# Epoch 41/50
# 18000/18000 [==============================] - 6s 357us/step - loss: 0.1630 - acc: 0.7642 - val_loss: 0.1988 - val_acc: 0.6898
# Epoch 42/50
# 18000/18000 [==============================] - 6s 360us/step - loss: 0.1624 - acc: 0.7661 - val_loss: 0.1993 - val_acc: 0.6896
# Epoch 43/50
# 18000/18000 [==============================] - 7s 363us/step - loss: 0.1620 - acc: 0.7669 - val_loss: 0.1993 - val_acc: 0.6904
# Epoch 44/50
# 18000/18000 [==============================] - 7s 366us/step - loss: 0.1618 - acc: 0.7683 - val_loss: 0.1982 - val_acc: 0.6937
# Epoch 45/50
# 18000/18000 [==============================] - 7s 369us/step - loss: 0.1615 - acc: 0.7679 - val_loss: 0.1989 - val_acc: 0.6907
# Epoch 46/50
# 18000/18000 [==============================] - 7s 378us/step - loss: 0.1606 - acc: 0.7704 - val_loss: 0.1987 - val_acc: 0.6936
# Epoch 47/50
# 18000/18000 [==============================] - 7s 363us/step - loss: 0.1605 - acc: 0.7717 - val_loss: 0.1996 - val_acc: 0.6900
# Epoch 48/50
# 18000/18000 [==============================] - 6s 359us/step - loss: 0.1603 - acc: 0.7716 - val_loss: 0.1990 - val_acc: 0.6929
# Epoch 49/50
# 18000/18000 [==============================] - 6s 357us/step - loss: 0.1599 - acc: 0.7713 - val_loss: 0.1997 - val_acc: 0.6913
# Epoch 50/50
# 18000/18000 [==============================] - 7s 367us/step - loss: 0.1597 - acc: 0.7711 - val_loss: 0.2008 - val_acc: 0.6870
# Training time finished.
# 50 epochs in 0:05:29.471893

# %%
# Plot accuracy
plt.plot(m2.history["acc"])
plt.plot(m2.history["val_acc"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train", "Validation"], loc = "upper left")
plt.show()

# Plot loss
plt.plot(m2.history["loss"])
plt.plot(m2.history["val_loss"])
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Validation"], loc = "upper right")
plt.show()

# %% [markdown]
# # Siamese FNN
#
# * siamese network with a basic feed-forward network
# * input > embeddings > 3x dense > distance
# * distance function = euclidean distance
# * loss function = mean squared error
# * optimizer = RMSprop

# %%
def g4(
    data, 
    labels, 
    embedding_layer,
    split,
    seq_shape):
    '''
    basic siamese network with CNN
    
    params
        data
        labels
        embedding_layer
        split
        seq_shape
    
    see
    https://keras.io/examples/mnist_siamese/
    https://github.com/keras-team/keras/blob/master/examples/mnist_siamese.py
    https://sorenbouma.github.io/blog/oneshot/
    https://towardsdatascience.com/one-shot-learning-with-siamese-networks-using-keras-17f34e75bb3d
    https://github.com/sorenbouma/keras-oneshot/blob/master/SiameseNet.ipynb
    
    https://medium.com/mlreview/implementing-malstm-on-kaggles-quora-question-pairs-competition-8b31b0b16a07
    https://github.com/eliorc/Medium/blob/master/MaLSTM.ipynb
    https://www.aaai.org/ocs/index.php/AAAI/AAAI16/paper/download/12195/12023
    '''
    
    def split_data(data, labels, split, random_state = 0):
        '''
        split the data into a training set and a validation set
        note for this to simulate catalog data, we need stratified split, per class

        params
            data
                matrix of vectorized text data
            labels
                array of label ids for each of the texts
            labels_oh
                one-hot matrix of labels for each of the texts
            split
                float that represnets the validation split size
        '''
        np.random.seed(random_state)
        x_train = np.empty((0, data[0].shape[0]))
        y_train = np.empty((0, ))
        x_val = np.empty((0, data[0].shape[0]))
        y_val = np.empty((0, ))

        # gets unique classes
        uc = np.unique(labels)

        # for each class, 
        # subsets the data and labels, 
        # and assigns some to train, some to validation 
        # this makes sure each class has some representation in train, and some in validation
        for c in uc:
            t1 = (labels == c)
            t2 = np.array(labels)
            data_c = data[t1]
            labels_c = t2[t1]
            indices = np.arange(data_c.shape[0])
            np.random.shuffle(indices)
            data_c = data_c[indices]
            labels_c = labels_c[indices]
            num_validation_samples = int(split * data_c.shape[0])
            x_train_c = data_c[:-num_validation_samples]
            y_train_c = labels_c[:-num_validation_samples]
            x_val_c = data_c[-num_validation_samples:]
            y_val_c = labels_c[-num_validation_samples:]
            
            x_train = np.concatenate([x_train, x_train_c])
            y_train = np.concatenate([y_train, y_train_c])
            x_val = np.concatenate([x_val, x_val_c])
            y_val = np.concatenate([y_val, y_val_c])

        return(x_train, y_train, x_val, y_val)
    
    def create_pairs(x, unspsc_indices, num_classes):
        '''
        Positive and negative pair creation.
        Alternates between positive and negative pairs.

        params
            x
                either the train or validation set
            unspsc_indices
                indices of which x belongs to which class
            num_classes
                number of unique classes

        see https://github.com/keras-team/keras/blob/master/examples/mnist_siamese.py
        '''
        pairs = []
        labels = []
        n = min([len(unspsc_indices[d]) for d in range(num_classes)]) - 1
        for d in range(num_classes):
            for i in range(n):
                z1, z2 = unspsc_indices[d][i], unspsc_indices[d][i + 1]
                pairs += [[x[z1], x[z2]]]
                inc = random.randrange(1, num_classes)
                dn = (d + inc) % num_classes
                z1, z2 = unspsc_indices[d][i], unspsc_indices[dn][i]
                pairs += [[x[z1], x[z2]]]
                labels += [1, 0]
        return np.array(pairs), np.array(labels)
    
    def euclidean_distance(vects):
        # euclidean distance might not work, 
        # see Chopra, Hadsell, and LeCun (2005)
        # and Mueller et al (2016)
        x, y = vects
        sum_square = K.sum(K.square(x - y), axis=1, keepdims=True)
        return K.sqrt(K.maximum(sum_square, K.epsilon()))
    
    def eucl_dist_output_shape(shapes):
        shape1, shape2 = shapes
        return (shape1[0], 1)
    
    
    n_hidden = 10
    gradient_clipping_norm = 1.25
    batch_size = 128
    n_epoch = 50
    learning_rate = 0.001
    
    # split the vectorized data into train and validation sets
    x_train, y_train, x_val, y_val = split_data(data, labels, split)
    
    # gets unique classes
    num_classes = len(np.unique(labels))
    
    # creates the pairs
    unspsc_indices = [np.where(y_train == i)[0] for i in range(num_classes)]
    tr_pairs, tr_y = create_pairs(x_train, unspsc_indices, num_classes)

    unspsc_indices = [np.where(y_val == i)[0] for i in range(num_classes)]
    vl_pairs, vl_y = create_pairs(x_val, unspsc_indices, num_classes)
    
    # network definition
    x = Sequential()
    x.add(embedding_layer)
    x.add(Dense(128, activation='relu'))
    x.add(Dense(128, activation='relu'))
    x.add(Dense(128, activation='relu'))
    shared_model = x
    
    # The visible layer
    input_a = Input(shape = (seq_shape,), dtype='int32')
    input_b = Input(shape = (seq_shape,), dtype='int32')
    shared_a = shared_model(input_a)
    shared_b = shared_model(input_b)
    
    # Euclidean distance
    distance = Lambda(
        function = euclidean_distance, 
        output_shape = eucl_dist_output_shape
    )([shared_a, shared_b])
    
    # Pack it all up into a model
    model = Model([input_a, input_b], [distance])
    
    # RMSprop optimizer
    optimizer = RMSprop(lr = learning_rate)
    
    model.compile(loss = "mean_squared_error", optimizer = optimizer, metrics = ["accuracy"])
    
    # Start training
    training_start_time = time() # this is just for timing the runs
    
    # fit model on, 
    #    the tr_pairs 0 texts (left side) vs the tr_pairs 1 texts (right side)
    #    along with the binary labels if they are same class or not tr_y
    # validate model on,
    #    the vl_pairs 0 texts (left side) vs the vl_pairs 1 texts (right side)
    #    and their true binary labels if they are same class or not vl_y
    model_trained = model.fit([tr_pairs[:, 0], tr_pairs[:, 1]], tr_y,
          batch_size = batch_size,
          epochs = n_epoch,
          validation_data = ([vl_pairs[:, 0], vl_pairs[:, 1]], vl_y))
    
    print("Training time finished.\n{} epochs in {}".format(n_epoch, datetime.timedelta(seconds=time()-training_start_time)))
    
    return(model_trained)

m4 = g4( data = data, 
    labels = labels, 
    embedding_layer = embedding_layer,
    split = VALIDATION_SPLIT,
    seq_shape = MAX_SEQUENCE_LENGTH)
# Out:
# Train on 18000 samples, validate on 18000 samples
# Epoch 1/50
# 18000/18000 [==============================] - 18s 1ms/step - loss: 0.2969 - acc: 0.5009 - val_loss: 0.2924 - val_acc: 0.5000
# Epoch 2/50
# 18000/18000 [==============================] - 18s 989us/step - loss: 0.2911 - acc: 0.5000 - val_loss: 0.2914 - val_acc: 0.5000
# Epoch 3/50
# 18000/18000 [==============================] - 18s 996us/step - loss: 0.2889 - acc: 0.5004 - val_loss: 0.2937 - val_acc: 0.5000
# Epoch 4/50
# 18000/18000 [==============================] - 18s 990us/step - loss: 0.2869 - acc: 0.5013 - val_loss: 0.2895 - val_acc: 0.5000
# Epoch 5/50
# 18000/18000 [==============================] - 18s 995us/step - loss: 0.2854 - acc: 0.5004 - val_loss: 0.2917 - val_acc: 0.5000
# Epoch 6/50
# 18000/18000 [==============================] - 18s 999us/step - loss: 0.2844 - acc: 0.4997 - val_loss: 0.2907 - val_acc: 0.5000
# Epoch 7/50
# 18000/18000 [==============================] - 18s 997us/step - loss: 0.2834 - acc: 0.4990 - val_loss: 0.2881 - val_acc: 0.5000
# Epoch 8/50
# 18000/18000 [==============================] - 18s 991us/step - loss: 0.2821 - acc: 0.5001 - val_loss: 0.2872 - val_acc: 0.5000
# Epoch 9/50
# 18000/18000 [==============================] - 18s 987us/step - loss: 0.2814 - acc: 0.4999 - val_loss: 0.2875 - val_acc: 0.5000
# Epoch 10/50
# 18000/18000 [==============================] - 18s 989us/step - loss: 0.2804 - acc: 0.5005 - val_loss: 0.2884 - val_acc: 0.5000
# Epoch 11/50
# 18000/18000 [==============================] - 18s 980us/step - loss: 0.2801 - acc: 0.4994 - val_loss: 0.2874 - val_acc: 0.5000
# Epoch 12/50
# 18000/18000 [==============================] - 18s 985us/step - loss: 0.2794 - acc: 0.4998 - val_loss: 0.2881 - val_acc: 0.5000
# Epoch 13/50
# 18000/18000 [==============================] - 18s 976us/step - loss: 0.2791 - acc: 0.4992 - val_loss: 0.2913 - val_acc: 0.5000
# Epoch 14/50
# 18000/18000 [==============================] - 18s 989us/step - loss: 0.2788 - acc: 0.4992 - val_loss: 0.2867 - val_acc: 0.5000
# Epoch 15/50
# 18000/18000 [==============================] - 18s 1ms/step - loss: 0.2784 - acc: 0.4995 - val_loss: 0.2898 - val_acc: 0.5000
# Epoch 16/50
# 18000/18000 [==============================] - 18s 972us/step - loss: 0.2781 - acc: 0.4991 - val_loss: 0.2865 - val_acc: 0.5000
# Epoch 17/50
# 18000/18000 [==============================] - 18s 973us/step - loss: 0.2777 - acc: 0.4999 - val_loss: 0.2868 - val_acc: 0.5000
# Epoch 18/50
# 18000/18000 [==============================] - 18s 989us/step - loss: 0.2775 - acc: 0.5000 - val_loss: 0.2864 - val_acc: 0.5000
# Epoch 19/50
# 18000/18000 [==============================] - 18s 986us/step - loss: 0.2773 - acc: 0.5005 - val_loss: 0.2864 - val_acc: 0.5000
# Epoch 20/50
# 18000/18000 [==============================] - 18s 993us/step - loss: 0.2772 - acc: 0.4996 - val_loss: 0.2867 - val_acc: 0.5000
# Epoch 21/50
# 18000/18000 [==============================] - 18s 978us/step - loss: 0.2774 - acc: 0.4988 - val_loss: 0.2860 - val_acc: 0.5000
# Epoch 22/50
# 18000/18000 [==============================] - 18s 975us/step - loss: 0.2771 - acc: 0.4988 - val_loss: 0.2909 - val_acc: 0.5000
# Epoch 23/50
# 18000/18000 [==============================] - 18s 987us/step - loss: 0.2767 - acc: 0.4997 - val_loss: 0.2890 - val_acc: 0.5000
# Epoch 24/50
# 18000/18000 [==============================] - 18s 976us/step - loss: 0.2765 - acc: 0.5010 - val_loss: 0.2856 - val_acc: 0.5000
# Epoch 25/50
# 18000/18000 [==============================] - 18s 990us/step - loss: 0.2763 - acc: 0.5009 - val_loss: 0.2858 - val_acc: 0.5000
# Epoch 26/50
# 18000/18000 [==============================] - 18s 985us/step - loss: 0.2762 - acc: 0.5002 - val_loss: 0.2888 - val_acc: 0.5000
# Epoch 27/50
# 18000/18000 [==============================] - 18s 994us/step - loss: 0.2760 - acc: 0.5006 - val_loss: 0.2857 - val_acc: 0.5000
# Epoch 28/50
# 18000/18000 [==============================] - 18s 991us/step - loss: 0.2761 - acc: 0.4997 - val_loss: 0.2873 - val_acc: 0.5000
# Epoch 29/50
# 18000/18000 [==============================] - 18s 984us/step - loss: 0.2763 - acc: 0.4992 - val_loss: 0.2890 - val_acc: 0.5000
# Epoch 30/50
# 18000/18000 [==============================] - 18s 987us/step - loss: 0.2757 - acc: 0.5016 - val_loss: 0.2866 - val_acc: 0.5000
# Epoch 31/50
# 18000/18000 [==============================] - 18s 985us/step - loss: 0.2759 - acc: 0.4997 - val_loss: 0.2864 - val_acc: 0.5000
# Epoch 32/50
# 18000/18000 [==============================] - 18s 996us/step - loss: 0.2758 - acc: 0.5002 - val_loss: 0.2858 - val_acc: 0.5000
# Epoch 33/50
# 18000/18000 [==============================] - 18s 988us/step - loss: 0.2756 - acc: 0.5006 - val_loss: 0.2862 - val_acc: 0.5000
# Epoch 34/50
# 18000/18000 [==============================] - 17s 971us/step - loss: 0.2757 - acc: 0.4999 - val_loss: 0.2859 - val_acc: 0.5000
# Epoch 35/50
# 18000/18000 [==============================] - 18s 992us/step - loss: 0.2758 - acc: 0.4998 - val_loss: 0.2865 - val_acc: 0.5000
# Epoch 36/50
# 18000/18000 [==============================] - 18s 1ms/step - loss: 0.2756 - acc: 0.4996 - val_loss: 0.2856 - val_acc: 0.5000
# Epoch 37/50
# 18000/18000 [==============================] - 18s 1ms/step - loss: 0.2754 - acc: 0.5008 - val_loss: 0.2858 - val_acc: 0.5000
# Epoch 38/50
# 18000/18000 [==============================] - 18s 982us/step - loss: 0.2754 - acc: 0.4998 - val_loss: 0.2859 - val_acc: 0.5000
# Epoch 39/50
# 18000/18000 [==============================] - 17s 962us/step - loss: 0.2756 - acc: 0.4988 - val_loss: 0.2873 - val_acc: 0.5000
# Epoch 40/50
# 18000/18000 [==============================] - 18s 991us/step - loss: 0.2758 - acc: 0.4982 - val_loss: 0.2866 - val_acc: 0.5000
# Epoch 41/50
# 18000/18000 [==============================] - 18s 1ms/step - loss: 0.2757 - acc: 0.4993 - val_loss: 0.2856 - val_acc: 0.5000
# Epoch 42/50
# 18000/18000 [==============================] - 17s 967us/step - loss: 0.2753 - acc: 0.4996 - val_loss: 0.2864 - val_acc: 0.5000
# Epoch 43/50
# 18000/18000 [==============================] - 18s 982us/step - loss: 0.2751 - acc: 0.4999 - val_loss: 0.2876 - val_acc: 0.5000
# Epoch 44/50
# 18000/18000 [==============================] - 18s 985us/step - loss: 0.2755 - acc: 0.4993 - val_loss: 0.2860 - val_acc: 0.5000
# Epoch 45/50
# 18000/18000 [==============================] - 18s 979us/step - loss: 0.2752 - acc: 0.4998 - val_loss: 0.2858 - val_acc: 0.5000
# Epoch 46/50
# 18000/18000 [==============================] - 18s 979us/step - loss: 0.2750 - acc: 0.5003 - val_loss: 0.2859 - val_acc: 0.5000
# Epoch 47/50
# 18000/18000 [==============================] - 18s 987us/step - loss: 0.2751 - acc: 0.5004 - val_loss: 0.2884 - val_acc: 0.5000
# Epoch 48/50
# 18000/18000 [==============================] - 18s 1ms/step - loss: 0.2750 - acc: 0.4998 - val_loss: 0.2872 - val_acc: 0.5000
# Epoch 49/50
# 18000/18000 [==============================] - 18s 979us/step - loss: 0.2753 - acc: 0.4996 - val_loss: 0.2864 - val_acc: 0.5000
# Epoch 50/50
# 18000/18000 [==============================] - 17s 961us/step - loss: 0.2751 - acc: 0.5002 - val_loss: 0.2872 - val_acc: 0.5000
# Training time finished.
# 50 epochs in 0:14:49.892910

# %%
# Plot accuracy
plt.plot(m4.history["acc"])
plt.plot(m4.history["val_acc"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train", "Validation"], loc = "upper left")
plt.show()

# Plot loss
plt.plot(m4.history["loss"])
plt.plot(m4.history["val_loss"])
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Validation"], loc = "upper right")
plt.show()

# %% [markdown]
# # Siamese LSTM, flavor 2
#
# * input > embedding > 8x LSTM > distance
# * distance function = euclidean function
# * loss function = mean squared error
# * optimizer = Adam

# %%
def g5(
    data, 
    labels, 
    embedding_layer,
    split,
    seq_shape):
    '''
    basic siamese network with FNN with cross entropy loss
    
    params
        data
        labels
        embedding_layer
        split
        seq_shape
    
    see
    https://keras.io/examples/mnist_siamese/
    https://github.com/keras-team/keras/blob/master/examples/mnist_siamese.py
    https://sorenbouma.github.io/blog/oneshot/
    https://towardsdatascience.com/one-shot-learning-with-siamese-networks-using-keras-17f34e75bb3d
    https://github.com/sorenbouma/keras-oneshot/blob/master/SiameseNet.ipynb
    
    https://medium.com/mlreview/implementing-malstm-on-kaggles-quora-question-pairs-competition-8b31b0b16a07
    https://github.com/eliorc/Medium/blob/master/MaLSTM.ipynb
    https://www.aaai.org/ocs/index.php/AAAI/AAAI16/paper/download/12195/12023
    '''
    
    def split_data(data, labels, split, random_state = 0):
        '''
        split the data into a training set and a validation set
        note for this to simulate catalog data, we need stratified split, per class

        params
            data
                matrix of vectorized text data
            labels
                array of label ids for each of the texts
            labels_oh
                one-hot matrix of labels for each of the texts
            split
                float that represnets the validation split size
        '''
        np.random.seed(random_state)
        x_train = np.empty((0, data[0].shape[0]))
        y_train = np.empty((0, ))
        x_val = np.empty((0, data[0].shape[0]))
        y_val = np.empty((0, ))

        # gets unique classes
        uc = np.unique(labels)

        # for each class, 
        # subsets the data and labels, 
        # and assigns some to train, some to validation 
        # this makes sure each class has some representation in train, and some in validation
        for c in uc:
            t1 = (labels == c)
            t2 = np.array(labels)
            data_c = data[t1]
            labels_c = t2[t1]
            indices = np.arange(data_c.shape[0])
            np.random.shuffle(indices)
            data_c = data_c[indices]
            labels_c = labels_c[indices]
            num_validation_samples = int(split * data_c.shape[0])
            x_train_c = data_c[:-num_validation_samples]
            y_train_c = labels_c[:-num_validation_samples]
            x_val_c = data_c[-num_validation_samples:]
            y_val_c = labels_c[-num_validation_samples:]
            
            x_train = np.concatenate([x_train, x_train_c])
            y_train = np.concatenate([y_train, y_train_c])
            x_val = np.concatenate([x_val, x_val_c])
            y_val = np.concatenate([y_val, y_val_c])

        return(x_train, y_train, x_val, y_val)
    
    def create_pairs(x, unspsc_indices, num_classes):
        '''
        Positive and negative pair creation.
        Alternates between positive and negative pairs.

        params
            x
                either the train or validation set
            unspsc_indices
                indices of which x belongs to which class
            num_classes
                number of unique classes

        see https://github.com/keras-team/keras/blob/master/examples/mnist_siamese.py
        '''
        pairs = []
        labels = []
        n = min([len(unspsc_indices[d]) for d in range(num_classes)]) - 1
        for d in range(num_classes):
            for i in range(n):
                z1, z2 = unspsc_indices[d][i], unspsc_indices[d][i + 1]
                pairs += [[x[z1], x[z2]]]
                inc = random.randrange(1, num_classes)
                dn = (d + inc) % num_classes
                z1, z2 = unspsc_indices[d][i], unspsc_indices[dn][i]
                pairs += [[x[z1], x[z2]]]
                labels += [1, 0]
        return np.array(pairs), np.array(labels)
    
    def exponent_neg_manhattan_distance(a, b):
        ''' 
        Helper function for the similarity estimate of the LSTMs outputs
        params
            a
                the "left" text
            b
                the "right" text
        '''
        return K.exp(-K.sum(K.abs(a-b), axis=1, keepdims=True))
    
    
    n_hidden = 8
    gradient_clipping_norm = 1.25
    batch_size = 128
    n_epoch = 50
    learning_rate = 0.001
    
    # split the vectorized data into train and validation sets
    x_train, y_train, x_val, y_val = split_data(data, labels, split)
    
    # gets unique classes
    num_classes = len(np.unique(labels))
    
    # creates the pairs
    unspsc_indices = [np.where(y_train == i)[0] for i in range(num_classes)]
    tr_pairs, tr_y = create_pairs(x_train, unspsc_indices, num_classes)

    unspsc_indices = [np.where(y_val == i)[0] for i in range(num_classes)]
    vl_pairs, vl_y = create_pairs(x_val, unspsc_indices, num_classes)
    
    # Define the shared model
    # this is similar to the architecture from the paper
    # https://github.com/dhwajraj/deep-siamese-text-similarity
    x = Sequential()
    x.add(embedding_layer)
    # LSTM
    x.add(LSTM(n_hidden))
    shared_model = x
    
    # The visible layer
    input_a = Input(shape = (seq_shape,), dtype='int32')
    input_b = Input(shape = (seq_shape,), dtype='int32')
    shared_a = shared_model(input_a)
    shared_b = shared_model(input_b)
    
    # Calculates the distance as defined by the MaLSTM model
    # https://www.aaai.org/ocs/index.php/AAAI/AAAI16/paper/download/12195/12023
    distance = Lambda(
        function = lambda x: exponent_neg_manhattan_distance(x[0], x[1]),
        output_shape = lambda x: (x[0][0], 1)
    )([shared_a, shared_b])
    
    # Pack it all up into a model
    model = Model([input_a, input_b], [distance])
    
    # RMSprop optimizer
    optimizer = Adam(lr = learning_rate)
    
    model.compile(loss = "mean_squared_error", optimizer = optimizer, metrics = ["accuracy"])
    model.summary()
    shared_model.summary()
    
    # Start training
    training_start_time = time() # this is just for timing the runs
    
    # fit model on, 
    #    the tr_pairs 0 texts (left side) vs the tr_pairs 1 texts (right side)
    #    along with the binary labels if they are same class or not tr_y
    # validate model on,
    #    the vl_pairs 0 texts (left side) vs the vl_pairs 1 texts (right side)
    #    and their true binary labels if they are same class or not vl_y
    model_trained = model.fit([tr_pairs[:, 0], tr_pairs[:, 1]], tr_y,
          batch_size = batch_size,
          epochs = n_epoch,
          validation_data = ([vl_pairs[:, 0], vl_pairs[:, 1]], vl_y))
    
    print("Training time finished.\n{} epochs in {}".format(n_epoch, datetime.timedelta(seconds=time()-training_start_time)))
    
    return(model_trained)

m5 = g5( data = data, 
    labels = labels, 
    embedding_layer = embedding_layer,
    split = VALIDATION_SPLIT,
    seq_shape = MAX_SEQUENCE_LENGTH)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 20)           0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            (None, 20)           0
# __________________________________________________________________________________________________
# sequential_2 (Sequential)       (None, 8)            1404688     input_6[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 1)            0           sequential_2[1][0]
#                                                                  sequential_2[2][0]
# ==================================================================================================
# Total params: 1,404,688
# Trainable params: 3,488
# Non-trainable params: 1,401,200
# __________________________________________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 20, 100)           1401200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 8)                 3488
# =================================================================
# Total params: 1,404,688
# Trainable params: 3,488
# Non-trainable params: 1,401,200
# _________________________________________________________________
# Train on 18000 samples, validate on 18000 samples
# Epoch 1/50
# 18000/18000 [==============================] - 8s 454us/step - loss: 0.2950 - acc: 0.5447 - val_loss: 0.2458 - val_acc: 0.5882
# Epoch 2/50
# 18000/18000 [==============================] - 7s 365us/step - loss: 0.2350 - acc: 0.6128 - val_loss: 0.2323 - val_acc: 0.6176
# Epoch 3/50
# 18000/18000 [==============================] - 7s 366us/step - loss: 0.2255 - acc: 0.6319 - val_loss: 0.2261 - val_acc: 0.6323
# Epoch 4/50
# 18000/18000 [==============================] - 7s 393us/step - loss: 0.2175 - acc: 0.6492 - val_loss: 0.2204 - val_acc: 0.6424
# Epoch 5/50
# 18000/18000 [==============================] - 7s 370us/step - loss: 0.2119 - acc: 0.6636 - val_loss: 0.2172 - val_acc: 0.6485
# Epoch 6/50
# 18000/18000 [==============================] - 7s 368us/step - loss: 0.2076 - acc: 0.6715 - val_loss: 0.2154 - val_acc: 0.6557
# Epoch 7/50
# 18000/18000 [==============================] - 7s 371us/step - loss: 0.2036 - acc: 0.6800 - val_loss: 0.2123 - val_acc: 0.6583
# Epoch 8/50
# 18000/18000 [==============================] - 6s 357us/step - loss: 0.2001 - acc: 0.6871 - val_loss: 0.2105 - val_acc: 0.6619
# Epoch 9/50
# 18000/18000 [==============================] - 6s 360us/step - loss: 0.1972 - acc: 0.6936 - val_loss: 0.2088 - val_acc: 0.6657
# Epoch 10/50
# 18000/18000 [==============================] - 6s 356us/step - loss: 0.1948 - acc: 0.6944 - val_loss: 0.2098 - val_acc: 0.6668
# Epoch 11/50
# 18000/18000 [==============================] - 6s 361us/step - loss: 0.1926 - acc: 0.7019 - val_loss: 0.2071 - val_acc: 0.6718
# Epoch 12/50
# 18000/18000 [==============================] - 7s 389us/step - loss: 0.1903 - acc: 0.7062 - val_loss: 0.2069 - val_acc: 0.6712
# Epoch 13/50
# 18000/18000 [==============================] - 7s 373us/step - loss: 0.1884 - acc: 0.7141 - val_loss: 0.2055 - val_acc: 0.6742
# Epoch 14/50
# 18000/18000 [==============================] - 6s 346us/step - loss: 0.1867 - acc: 0.7158 - val_loss: 0.2063 - val_acc: 0.6740
# Epoch 15/50
# 18000/18000 [==============================] - 7s 371us/step - loss: 0.1851 - acc: 0.7174 - val_loss: 0.2046 - val_acc: 0.6758
# Epoch 16/50
# 18000/18000 [==============================] - 6s 358us/step - loss: 0.1836 - acc: 0.7218 - val_loss: 0.2050 - val_acc: 0.6748
# Epoch 17/50
# 18000/18000 [==============================] - 6s 360us/step - loss: 0.1824 - acc: 0.7247 - val_loss: 0.2036 - val_acc: 0.6811
# Epoch 18/50
# 18000/18000 [==============================] - 6s 354us/step - loss: 0.1813 - acc: 0.7261 - val_loss: 0.2036 - val_acc: 0.6807
# Epoch 19/50
# 18000/18000 [==============================] - 7s 364us/step - loss: 0.1801 - acc: 0.7294 - val_loss: 0.2033 - val_acc: 0.6794
# Epoch 20/50
# 18000/18000 [==============================] - 7s 370us/step - loss: 0.1791 - acc: 0.7325 - val_loss: 0.2026 - val_acc: 0.6813
# Epoch 21/50
# 18000/18000 [==============================] - 7s 369us/step - loss: 0.1781 - acc: 0.7335 - val_loss: 0.2024 - val_acc: 0.6812
# Epoch 22/50
# 18000/18000 [==============================] - 7s 362us/step - loss: 0.1772 - acc: 0.7334 - val_loss: 0.2019 - val_acc: 0.6828
# Epoch 23/50
# 18000/18000 [==============================] - 6s 355us/step - loss: 0.1761 - acc: 0.7381 - val_loss: 0.2020 - val_acc: 0.6829
# Epoch 24/50
# 18000/18000 [==============================] - 6s 356us/step - loss: 0.1753 - acc: 0.7377 - val_loss: 0.2013 - val_acc: 0.6851
# Epoch 25/50
# 18000/18000 [==============================] - 7s 362us/step - loss: 0.1745 - acc: 0.7393 - val_loss: 0.2021 - val_acc: 0.6817
# Epoch 26/50
# 18000/18000 [==============================] - 7s 364us/step - loss: 0.1740 - acc: 0.7421 - val_loss: 0.2025 - val_acc: 0.6824
# Epoch 27/50
# 18000/18000 [==============================] - 6s 343us/step - loss: 0.1729 - acc: 0.7422 - val_loss: 0.2009 - val_acc: 0.6829
# Epoch 28/50
# 18000/18000 [==============================] - 6s 349us/step - loss: 0.1722 - acc: 0.7444 - val_loss: 0.2019 - val_acc: 0.6826
# Epoch 29/50
# 18000/18000 [==============================] - 6s 352us/step - loss: 0.1718 - acc: 0.7461 - val_loss: 0.2022 - val_acc: 0.6831
# Epoch 30/50
# 18000/18000 [==============================] - 6s 358us/step - loss: 0.1712 - acc: 0.7472 - val_loss: 0.2019 - val_acc: 0.6850
# Epoch 31/50
# 18000/18000 [==============================] - 6s 355us/step - loss: 0.1702 - acc: 0.7482 - val_loss: 0.2018 - val_acc: 0.6847
# Epoch 32/50
# 18000/18000 [==============================] - 7s 367us/step - loss: 0.1698 - acc: 0.7518 - val_loss: 0.2023 - val_acc: 0.6829
# Epoch 33/50
# 18000/18000 [==============================] - 6s 359us/step - loss: 0.1690 - acc: 0.7518 - val_loss: 0.2018 - val_acc: 0.6857
# Epoch 34/50
# 18000/18000 [==============================] - 7s 361us/step - loss: 0.1685 - acc: 0.7524 - val_loss: 0.2014 - val_acc: 0.6847
# Epoch 35/50
# 18000/18000 [==============================] - 6s 358us/step - loss: 0.1682 - acc: 0.7537 - val_loss: 0.2019 - val_acc: 0.6847
# Epoch 36/50
# 18000/18000 [==============================] - 7s 371us/step - loss: 0.1675 - acc: 0.7559 - val_loss: 0.2017 - val_acc: 0.6824
# Epoch 37/50
# 18000/18000 [==============================] - 6s 356us/step - loss: 0.1675 - acc: 0.7556 - val_loss: 0.2024 - val_acc: 0.6844
# Epoch 38/50
# 18000/18000 [==============================] - 6s 353us/step - loss: 0.1666 - acc: 0.7567 - val_loss: 0.2026 - val_acc: 0.6830
# Epoch 39/50
# 18000/18000 [==============================] - 6s 357us/step - loss: 0.1662 - acc: 0.7601 - val_loss: 0.2033 - val_acc: 0.6796
# Epoch 40/50
# 18000/18000 [==============================] - 6s 353us/step - loss: 0.1656 - acc: 0.7597 - val_loss: 0.2027 - val_acc: 0.6823
# Epoch 41/50
# 18000/18000 [==============================] - 6s 355us/step - loss: 0.1654 - acc: 0.7614 - val_loss: 0.2028 - val_acc: 0.6840
# Epoch 42/50
# 18000/18000 [==============================] - 6s 355us/step - loss: 0.1646 - acc: 0.7615 - val_loss: 0.2032 - val_acc: 0.6832
# Epoch 43/50
# 18000/18000 [==============================] - 7s 363us/step - loss: 0.1645 - acc: 0.7636 - val_loss: 0.2029 - val_acc: 0.6829
# Epoch 44/50
# 18000/18000 [==============================] - 7s 366us/step - loss: 0.1636 - acc: 0.7648 - val_loss: 0.2025 - val_acc: 0.6821
# Epoch 45/50
# 18000/18000 [==============================] - 6s 359us/step - loss: 0.1634 - acc: 0.7653 - val_loss: 0.2029 - val_acc: 0.6830
# Epoch 46/50
# 18000/18000 [==============================] - 7s 361us/step - loss: 0.1628 - acc: 0.7680 - val_loss: 0.2020 - val_acc: 0.6854
# Epoch 47/50
# 18000/18000 [==============================] - 7s 362us/step - loss: 0.1627 - acc: 0.7662 - val_loss: 0.2034 - val_acc: 0.6831
# Epoch 48/50
# 18000/18000 [==============================] - 6s 348us/step - loss: 0.1628 - acc: 0.7684 - val_loss: 0.2037 - val_acc: 0.6784
# Epoch 49/50
# 18000/18000 [==============================] - 6s 344us/step - loss: 0.1620 - acc: 0.7675 - val_loss: 0.2041 - val_acc: 0.6793
# Epoch 50/50
# 18000/18000 [==============================] - 6s 354us/step - loss: 0.1621 - acc: 0.7708 - val_loss: 0.2048 - val_acc: 0.6790
# Training time finished.
# 50 epochs in 0:05:28.064368

# %%
# Plot accuracy
plt.plot(m5.history["acc"])
plt.plot(m5.history["val_acc"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train", "Validation"], loc = "upper left")
plt.show()

# Plot loss
plt.plot(m5.history["loss"])
plt.plot(m5.history["val_loss"])
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Validation"], loc = "upper right")
plt.show()

# %% [markdown]
# # Conclusion
#
# The final results of this project were not anywhere close to the state of art, which is around mid 80% in Mueller et al. However, when comparing against each other, the techniques used in this project does demonstrate that the siamese architecture is very effective in applications where the number of classes of documents are much higher relative to the number of instances of each class.
#
# Note, item names and descriptions tend to use different words from natural English. Our choice of using pre-train embeddings GloVe might be negatively affecting the accuracy.
#
# This is vulnerable to items being thrown into the most permissive category. Will tend to select for those categories since they will have the most item names. Less appetizing for business use, since often the business aim of categorization exercises is to build a better balanced categorization that is more expressive and can be used for downstream analytics. Maybe this approach can be complemented by negatively weighing the more popular categories.
